# %%
import ClusterViz

# %%
s1 = 'Der Beginn des Versicherungsvertrags darf frei von bekannten Schäden und Verstößen maximal 3 Monate in der Vergangenheit liegen.'
s2 = 'Der Beginn des Versicherungsvertrags darf frei von bekannten Schäden und Verstößen maximal 3 Monate in der Vergangenheit und maximal 12 Monate in der Zukunft liegen.'
s3 = 'Beginn des Versicherungsvertrags darf frei von bekannten Schäden und Verstößen maximal 6 Monate in der Vergangenheit liegen.'

cluster = [s1, s2, s3]


ClusterViz.visualize(cluster,"ClusterImg",".",0)
#Argument 1: The list of sentences to visualize
#Argument 2: Name of output file
#Argument 3: Output directory
#Argument 4: Number of the sentence that should be typeset in bold face

# %%
from IPython.display import Image
Image('ClusterImg.gv.png')
